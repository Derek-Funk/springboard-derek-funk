# %%
dbutils.notebook.run("guidedcapstonestep2", timeout_seconds=60) #38s
dbutils.notebook.run("guidedcapstonestep3", timeout_seconds=60) #48s
dbutils.notebook.run("guidedcapstonestep4", timeout_seconds=60) #24s
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
